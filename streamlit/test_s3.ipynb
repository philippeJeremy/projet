# %%
import pandas as pd
df = pd.read_csv("https://data-vins.s3.amazonaws.com/vins.csv")

# %%
category = "Fromages"
newdf = df.loc[df['target'] == category]
newdf
# Out:
#       target                               vin   type                region
# 0   Fromages                        Vacqueyras  Rouge                 Rhône
# 1   Fromages                    Côtes du Rhône  Rouge                 Rhône
# 2   Fromages           Côtes du Rhône Villages  Rouge                 Rhône
# 3   Fromages            Montagne Saint-Emilion  Rouge              Bordeaux
# 4   Fromages                  Côtes du Luberon  Rouge                 Rhône
# 5   Fromages  Cabernet-Sauvignon de Californie  Rouge            Californie
# 6   Fromages                    Pouilly Fuissé  Blanc             Bourgogne
# 7   Fromages                            Bandol   Rosé              Provence
# 8   Fromages                          Cadillac  Blanc              Bordeaux
# 9   Fromages                          Jurançon  Blanc              SudOuest
# 10  Fromages                          Loupiac   Blanc              Bordeaux
# ...
